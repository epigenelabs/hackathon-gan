# %%
import pandas as pd 

merged=pd.read_csv("merged_cancer_type_most_variant_train.csv",index_col=0)

# %%
breast=pd.read_csv("breast_most_variant_genes_train.csv",index_col=0)

# %%
col_to_keep=[col for col in merged.columns if col in breast.columns]

# %%
merged_data_to_use=merged[col_to_keep]

# %%
merged_data_to_use.to_csv("merged_data_to_use.csv")

# %%
merged1=pd.read_csv("merged_data_to_use.csv",index_col=0)
merged1
# Out:
#          GTEX-1RAZQ-1226-SM-EWRNL  CPT008755  GTEX-1MCYP-0126-SM-E6CIS  \
# EEF1A1                   354424.0   210034.0                  476211.0
# REG3A                         0.0        0.0                       1.0
# IGHA1                      2332.0    15975.0                    3206.0
# MALAT1                   232866.0   102356.0                   67015.0
# IGKC                       4496.0     8359.0                   10229.0
# ...                           ...        ...                       ...
# FLT4                       1757.0     1108.0                    4190.0
# SLC30A2                       9.0       10.0                      14.0
# GIMAP4                     2244.0      963.0                    2326.0
# TTLL12                     3243.0     1357.0                    1984.0
# JDP2                       1780.0      867.0                    2398.0
#
#          GTEX-15FZZ-0726-SM-7KUFZ  GTEX-11GSP-0926-SM-9WYSG  \
# ...

# %%
"CPT008755" in breast.columns
# Out:
# True
